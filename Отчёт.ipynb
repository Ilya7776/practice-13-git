# %% [markdown]
# # Титульный лист
# <a name = 'Титульный_лист'>

# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет по практической работе №12 </center>
# <center>по дисциплине </center>
# <center><b>«Введение в информационные технологии»</b></center>
# <center>на тему</center>
# <center><b>«Системы контроля версий»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК2408 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Четырин Илья Константинович</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Ассистент кафедры ТиЗВ Кудряшов Всеволод Владимирович </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Москва, 2024 г. </p>
#
#   <hr>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>Содержание</b></font>

# %% [markdown]
# [1. Титульный лист](#Титульный_лист)
#
# <a href = '#Постановка_задач'>2. Постановка задач </a>
#
# <a href = '#Ход_работы'>3. Ход работы </a>
#
# <a href = '#Результат_выполнения_работы'>4. Результат выполнения работы </a>
#
# <a href = '#Контрольное_задание_на_защиту'>5. Контрольное задание на защиту </a>

# %% [markdown]
# #<font size="6" color="black" face="Times"><b>Постановка задач</b></font>
#
# <a name = 'Постановка_задач'>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>Задание</b></font>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Создать локальный git репозиторий, сохранить в нем данный отчёт и зафиксировать все изменения, а после скопировать на github, также скопировать на github ранее созданный статический сайт. Дополнительное задание - скопировать на github динамический сайт.
# </div></font>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>Цель работы</b></font>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Локальный git репозиторий с файлом отчета, github репозиторий с файлом отчёта, статическим и динамическим сайтами.
# </div></font>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>Задачи работы</b></font>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# <ol>
# <li>установить git
# <li>создать локальный репозиторий с файлом отчёта
# <li>зафиксировать все изменения отчёта
# <li>залить отчёт на github
# <li>залить сайты на github
# </ol>

# %% [markdown]
# ##<font size="5" color="black" face="Times"><b>Расчет входных данных</b></font>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Компьютер, оснащенный операционной системой Windows, Unix-подобной либо MacOs и доступом в сеть Internet, компьютерная мышь и клавиатура для взаимодействия с ним, доступ к электросети, от которой будет работать данный компьютер. Браузер.
# </div></font>

# %% [markdown]
# <font size="6" color="black" face="Times"><b>Ход работы</b></font>
#
# <a name = 'Ход_работы'></a>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Скачиваем git для Windows и устаналиаем его (рис. 1).
# </div></font>

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="center"><b>Рисунок 1.</b> Установка Git
# </div></font>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Создаём папку для отчёта (в данном случае project), открываем её через cmd и инициализируем локальный репозиторий с помощью команды "git init" (рис. 2).
# </div></font>

# %% [markdown]
# ![6.png](data:image/png;base64,...)

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="center"><b>Рисунок 2.</b> Инициализируем локальный реозиторий
# </div></font>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Сохраняем отчет в папку project.
# </div></font>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Добавляем отчёт в репозиторий git, фиксируем изменения и создаём новую версию (рис. 3).
# </div></font>

# %% [markdown]
# ![8.png](data:image/png;base64,...)

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="center"><b>Рисунок 3.</b> Фиксация изменений
# </div></font>

# %% [markdown]
# <font size="3" color="black" face="Times"><div align="justify">
# &emsp;Создаем новую ветку с названием "branch_v2".
# </div></font>

# %% [markdown]
# #<font size="6" color="black" face="Times"><b>Результат выполнения работы</b></font>
# <a name = 'Результат_выполнения_работы'>

# %% [markdown]
# #<font size="6" color="black" face="Times"><b>Контрольное задание на защиту</b></font>
#
# <a name = 'Контрольное_задание_на_защиту'>
